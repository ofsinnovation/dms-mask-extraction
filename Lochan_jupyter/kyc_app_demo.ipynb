# %%
# conda create -n yourenvname python=x.x anaconda
# 
# using py37 virtual env for my reference
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import io
import os
import base64
# Imports the Google Cloud client library
# [START vision_python_migration_import]
#from google.cloud import vision
#from google.cloud.vision import types
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-6435792c1c05> in <module>
#       2 #
#       3 # using py37 virtual env for my reference
# ----> 4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 import matplotlib
#       6 import numpy as np
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# <decorator-gen-107> in matplotlib(self, line)
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3341         """
#    3342         from IPython.core import pylabtools as pt
# -> 3343         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3344
#    3345         if gui != 'inline':
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/IPython/core/pylabtools.py in find_gui_and_backend(gui, gui_select)
#     274     """
#     275
# --> 276     import matplotlib
#     277
#     278     if gui and gui != 'auto':
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/matplotlib/__init__.py in <module>
#     136 # cbook must import matplotlib only within function
#     137 # definitions, so it is safe to import from it here.
# --> 138 from . import cbook, rcsetup
#     139 from matplotlib.cbook import (
#     140     MatplotlibDeprecationWarning, dedent, get_label, sanitize_sequence)
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in <module>
#      29 from weakref import WeakMethod
#      30
# ---> 31 import numpy as np
#      32
#      33 import matplotlib
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/numpy/__init__.py in <module>
#     140     from . import _distributor_init
#     141
# --> 142     from . import core
#     143     from .core import *
#     144     from . import compat
#
# ~/anaconda2/envs/py37/lib/python3.7/site-packages/numpy/core/__init__.py in <module>
#      89         "numpy in {}. One method of fixing this is to repeatedly uninstall "
#      90         "numpy until none is found, then reinstall this version.")
# ---> 91     raise ImportError(msg.format(path))
#      92
#      93 from . import numerictypes as nt
#
# ImportError: Something is wrong with the numpy installation. While importing we detected an older version of numpy in ['/home/superadmin/anaconda2/envs/py37/lib/python3.7/site-packages/numpy']. One method of fixing this is to repeatedly uninstall numpy until none is found, then reinstall this version.

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])
def plot_strips_with_title(title):
    documents = list(parsed_image_dict['masks'].keys())
    for document in documents:
        if document in parsed_image_dict:
            strips = parsed_image_dict[document]
            imgs = [kyc_presenter._base64_to_numpy_array_(parsed_image_dict[document][strip]) for strip in strips]
            strip_titles = [strip_name for strip_name in strips]
            print(title)
    return plots(imgs, rows=1, titles=strip_titles, figsize=(16,8))

# %%
import all_in_one as demo
kyc_presenter = demo.KYC()

# %%
aadhaar_document_extraction_ip = '34.66.196.48:8080'
aadhaar_text_strip_extraction_ip = '34.66.196.48:8081'
document_classifier_ip = '34.66.196.48:8082'
document_orientation_classifier_ip = '34.66.196.48:8083'
pan_document_extraction_ip = '34.66.196.48:8084'
pan_text_strip_extraction_ip = '34.66.196.48:8085'
kyc_presenter.ip_dict = {'aadhaar_document_extraction':aadhaar_document_extraction_ip,
                         'aadhaar_text_strip_extraction':aadhaar_text_strip_extraction_ip,
                         'document_classifier':document_classifier_ip,
                         'document_orientation_classifier':document_orientation_classifier_ip,
                         'pan_document_extraction':pan_document_extraction_ip,
                         'pan_text_strip_extraction':pan_text_strip_extraction_ip
                        }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cb88122a5e6c> in <module>
#      10                          'document_orientation_classifier':document_orientation_classifier_ip,
#      11                          'pan_document_extraction':pan_document_extraction_ip,
# ---> 12                          'pan_text_strip_extraction':pan_text_strip_extraction_ip
#      13                         }
#
# NameError: name 'kyc_presenter' is not defined

# %%
kyc_presenter.class_mappings = {'document_orientation_classifier':None,
 'document_classifier':None,
 'aadhaar_text_strip_extraction':None,
 'aadhaar_document_extraction':{'1':"aadhar_half_front", '2':"aadhar_half_back"},
 'pan_text_strip_extraction':None,
 'pan_document_extraction': {'1':"pan_front"}}

# %%
parsed_image_dict = kyc_presenter.parse_image(image_path, orientation_correction=True, classify=True, class_name='pan')
# Out:
# document_orientation_classifier
# Expecting response
# print worker
# document_orientation_classifier
# <Response [200]>
# $$$$$$$$$$$$$$$$$$$$$
# done
# pan_document_extraction
# Expecting response
# print worker
# pan_document_extraction
# <Response [201]>
# $$$$$$$$$$$$$$$$$$$$$
# Len of data mask is
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-8ae81bf4a17e> in <module>
# ----> 1 parsed_image_dict = kyc_presenter.parse_image(image_path, orientation_correction=True, classify=True, class_name='pan')
#
# ~/amanbkp/Lochan/all_in_one.py in parse_image(self, image_path, classify, orientation_correction, document_extraction, text_strip_extraction, class_name)
#     253         :param classify:
#     254         :param orientation_correction:
# --> 255         :param document_extraction:
#     256         :param text_strip_extraction:
#     257         :param class_name:
#
# ~/amanbkp/Lochan/all_in_one.py in _get_required_item_(self, worker, material)
#     223         # print( "type of ip_dict" + type(self.ip_dict))
#     224         # print('http://' + self.ip_dict[worker] + '/' + worker)
# --> 225         # print("ip_dict")
#     226         print(self.ip_dict[str(worker)])
#     227         # return 'http://' + self.ip_dict[worker] + '/' + worker
#
# ~/amanbkp/Lochan/all_in_one.py in _parse_response_(self, worker, material, response)
#     129         print(self.DOCUMENT_EXTRACTOR_KEYWORD)
#     130         print("checking self.DOCUMENT_EXTRACTOR_KEYWORD")
# --> 131         elif self.DOCUMENT_EXTRACTOR_KEYWORD in worker:
#     132             # import pdb;pdb.set_trace()
#     133             parsed_response = {}
#
# ValueError: '_' is not in list

# %% [markdown]
# # Voter ID

# %%
# aadhaar_image = "/home/amank/Documents/datasets/instance_segmentation_vishnu/aadhar1_files/train/57a1abb2381884122b3cf91e.jpg"
# voter_image = '/home/amank/Documents/datasets//image_classification/chola/imgdata/VOTERID/VoterId1.jpg'
# pan_image = "/home/amank/Documents/datasets/instance_segmentation_vishnu/pan_dataset/val/57ecfb86ab076a78530ba344.jpg"
# driving = '/home/amank/Documents/datasets//image_classification/chola/imgdata/Driving/Driving0.jpg'
aadhaar_image = '/home/superadmin/amanbkp/Lochan/aadhar_front.png'
pan_image = '/home/superadmin/amanbkp/Lochan/pan_samplpe2.jpg'
plt.title('Original Image')
orignal_image = Image.open(aadhaar_image)
plt.imshow(orignal_image)

# %%
image_path = pan_image

parsed_image_dict = kyc_presenter.parse_image(image_path, classify=True)
# Out:
# document_classifier
# Expecting response
# print worker
# document_classifier
# <Response [201]>
# $$$$$$$$$$$$$$$$$$$$$
# Class is :pan

# %%
parsed_image_dict['class_name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-3a443e3f9a47> in <module>
# ----> 1 parsed_image_dict['class_name']
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# # Driving ID

# %%
driving = '/home/superadmin/amanbkp/Lochan/voterid.jpeg'
plt.title('Original Image')
orignal_image = Image.open(driving)
plt.imshow(orignal_image)

# %%
image_path = driving
parsed_image_dict = kyc_presenter.parse_image(image_path, classify=True)
# Out:
# document_classifier
# Expecting response
# print worker
# document_classifier
# <Response [201]>
# $$$$$$$$$$$$$$$$$$$$$
# Class is :Driving

# %%
parsed_image_dict['class_name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-3a443e3f9a47> in <module>
# ----> 1 parsed_image_dict['class_name']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
parsed_image_dict = kyc_presenter.parse_image(image_path, orientation_correction=True, classify=True, class_name='pan')
# Out:
# document_orientation_classifier
# Expecting response
# print worker
# document_orientation_classifier
# <Response [200]>
# $$$$$$$$$$$$$$$$$$$$$
# done
# pan_document_extraction
# Expecting response
# print worker
# pan_document_extraction
# <Response [201]>
# $$$$$$$$$$$$$$$$$$$$$
# Len of data mask is
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-191-8ae81bf4a17e> in <module>
# ----> 1 parsed_image_dict = kyc_presenter.parse_image(image_path, orientation_correction=True, classify=True, class_name='pan')
#
# ~/amanbkp/Lochan/all_in_one.py in parse_image(self, image_path, classify, orientation_correction, document_extraction, text_strip_extraction, class_name)
#     253         :param classify:
#     254         :param orientation_correction:
# --> 255         :param document_extraction:
#     256         :param text_strip_extraction:
#     257         :param class_name:
#
# ~/amanbkp/Lochan/all_in_one.py in _get_required_item_(self, worker, material)
#     223         # print( "type of ip_dict" + type(self.ip_dict))
#     224         # print('http://' + self.ip_dict[worker] + '/' + worker)
# --> 225         # print("ip_dict")
#     226         print(self.ip_dict[str(worker)])
#     227         # return 'http://' + self.ip_dict[worker] + '/' + worker
#
# ~/amanbkp/Lochan/all_in_one.py in _parse_response_(self, worker, material, response)
#     129         print(self.DOCUMENT_EXTRACTOR_KEYWORD)
#     130         print("checking self.DOCUMENT_EXTRACTOR_KEYWORD")
# --> 131         elif self.DOCUMENT_EXTRACTOR_KEYWORD in worker:
#     132             # import pdb;pdb.set_trace()
#     133             parsed_response = {}
#
# ValueError: '_' is not in list

# %%
#image_path = '/home/amank/Documents/datasets/instance_segmentation_vishnu/madhevan_pan.jpg'
image_path = '/home/superadmin/amanbkp/Lochan/pan_samplpe2.jpg'
parsed_image_dict = kyc_presenter.parse_image(image_path, orientation_correction=True, class_name='pan')
# Out:
# document_orientation_classifier
# Expecting response
# print worker
# document_orientation_classifier
# <Response [200]>
# $$$$$$$$$$$$$$$$$$$$$
# done
# pan_document_extraction
# Expecting response
# print worker
# pan_document_extraction
# <Response [201]>
# $$$$$$$$$$$$$$$$$$$$$
# Len of data mask is
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-b214a951dd72> in <module>
#       1 #image_path = '/home/amank/Documents/datasets/instance_segmentation_vishnu/madhevan_pan.jpg'
#       2 image_path = '/home/superadmin/amanbkp/Lochan/pan_samplpe2.jpg'
# ----> 3 parsed_image_dict = kyc_presenter.parse_image(image_path, orientation_correction=True, class_name='pan')
#
# ~/amanbkp/Lochan/all_in_one.py in parse_image(self, image_path, classify, orientation_correction, document_extraction, text_strip_extraction, class_name)
#     253         :param class_name:
#     254         :return:
# --> 255         """
#     256
#     257         response_dict = {}
#
# ~/amanbkp/Lochan/all_in_one.py in _get_required_item_(self, worker, material)
#     223         print('http://' + self.ip_dict[worker] + '/' + worker)
#     224
# --> 225         return 'http://' + self.ip_dict[worker] + '/' + worker
#     226     def _get_required_item_(self, worker, material):
#     227         """
#
# ~/amanbkp/Lochan/all_in_one.py in _parse_response_(self, worker, material, response)
#     129         print("checking self.DOCUMENT_EXTRACTOR_KEYWORD")
#     130         elif self.DOCUMENT_EXTRACTOR_KEYWORD in worker:
# --> 131             # import pdb;pdb.set_trace()
#     132             parsed_response = {}
#     133             print("DATA KEYS........")
#
# ValueError: '_' is not in list

# %%
parsed_image_dict['class_name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-3a443e3f9a47> in <module>
# ----> 1 parsed_image_dict['class_name']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# aadhaar_image = "/home/amank/Documents/datasets/instance_segmentation_vishnu/aadhar1_files/train/57a1abb2381884122b3cf91e.jpg"
# voter_image = '/home/amank/Documents/datasets/imgdata/VOTERID/VoterId1.jpg'
# pan_image = "/home/amank/Documents/datasets/instance_segmentation_vishnu/pan_dataset/val/.jpg"

# rotated_aadhaar_image = '/home/amank/Documents/datasets/instance_segmentation_vishnu/aadhar1_files/train/57e8d6b52c7587f3f25f717c.jpg'
# rotated_aadhar_image_1 ='/home/madhevan/Reorient_Dataset/Validate/FlipRight/Aadhaar_52.jpg'
# rotated_aadhar_image_2 ='/home/madhevan/Reorient_Dataset/Validate/FlipLeft/Aadhaar_35.jpg'
# rotated_aadhar_image_3 ='/home/madhevan/Reorient_Dataset/Validate/Inverted/Aadhaar_21_inv.jpg'
# rotated_pan_image_1 = '/home/madhevan/Reorient_Dataset/Validate/Inverted/148317904667110098477502.jpg'
# rotated_pan_image_2 = '/home/madhevan/Reorient_Dataset/Validate/FlipRight/146642622851117737498360.jpg'
# rotated_pan_image_2 = '/home/madhevan/Reorient_Dataset/Validate/Inverted/148283065714521097483266.jpg'
rotated_pan_image_3 = '/home/superadmin/amanbkp/Lochan/flipright.png'
#rotated_image_left = 
# image_path = rotated_aadhar_image_2
image_path = rotated_pan_image_3
plt.title('Orignal Image')
orignal_image = Image.open(image_path)
plt.imshow(orignal_image)

# %%
parsed_image_dict = kyc_presenter.parse_image(image_path, orientation_correction=True, classify=False, class_name='aadhaar')
